# %%
import wget
import calendar
import ujson
import gzip
import matplotlib
import pandas
import os
import re
import time
import pprint
import importlib
## functions
import github_parsing_functions as ghp

# %%
def parse_pull_request_events(json_data):
    result = {'event': 'PullRequestEvent'}
    result['repo_id'] = json_data['payload']['pull_request']['base']['repo']['id'] 
    result['repo_name'] = json_data['payload']['pull_request']['base']['repo']['name']
    result['description'] = json_data['payload']['pull_request']['base']['repo']['description']
    result['language'] = json_data['payload']['pull_request']['base']['repo']['language']
    result['stargazers_count'] = json_data['payload']['pull_request']['base']['repo']['stargazers_count']
    result['created_at'] = json_data['created_at']
    result['actor_id'] = json_data['actor']['id']
    result['actor_login'] = json_data['actor']['login']
    result['org'] = False
    result['org_id'] = None
    if 'org' in json_data:
        result['org'] = True
        result['org_id'] = json_data['org']['id']
    return result

def parse_pull_request_review_comment_events(json_data):
    result = {'event': 'PullRequestReviewCommentEvent'}
    result['language'] = json_data['payload']['pull_request']['base']['repo']['language'] 
    result["stargazers_count"] = json_data['payload']['pull_request']['base']['repo']["stargazers_count"] 
    result['repo_id'] = json_data['payload']['pull_request']['base']['repo']['id'] 
    result['repo_name'] = json_data['payload']['pull_request']['base']['repo']['full_name'] 
    result['created_at'] = json_data['created_at']
    result['actor_id'] = json_data['actor']['id']
    result['actor_login'] = json_data['actor']['login']
    result['org'] = False
    result['org_id'] = None
    if 'org' in json_data:
        result['org'] = True
        result['org_id'] = json_data['org']['id']
    return result

def parse_fork_event(json):
    result = {}
    result['event'] = 'ForkEvent'
    result['repo_id'] = json['repo']['id']
    result['repo_name'] = json['repo']['name']
    result['actor_id'] = json['actor']['id']
    result['actor_login'] = json['actor']['login']
    result['org'] = False
    result['org_id'] = None
    result['created_at'] = json['created_at']
    result['language'] = json['payload']['forkee']['language']
    result['stargazers_count'] = json['payload']['forkee']['stargazers_count']
    if 'org' in json:
        result['org'] = json['org']['id']
        result['org_id'] = json['org']['id']     
    return result

def parse_watch_event(json_data):
    result = {}
    result['created_at'] = json_data["created_at"]
    result['event'] = "WatchEvent"
    result['repo_id'] = json_data["repo"]["id"]
    result['repo_name'] = json_data["repo"]["name"]
    result['action'] = json_data["payload"]["action"]
    result['actor_id'] = json_data["actor"]["id"]
    result['actor_login'] = json_data["actor"]["login"]
    result['org'] = False
    result['org_id'] =  None
    if 'org' in json_data:
        result['org'] = True
        result['org_id'] = json_data["org"]["id"]
    return result

# %% [markdown]
# ### Download github archive files

# %%
url= 'http://data.githubarchive.org/2016-02-01-15.json.gz'
filename = wget.download(url)
filename
# Out:
# '2016-02-01-15.json (3).gz'

# %% [markdown]
# ### Parse out events

# %%
fork_event = []
watch_event = []
pr_event = []
pr_reviewcomment_event = []

# %%
with gzip.open('2016-02-01-15.json.gz') as f:   
    for i, line in enumerate(f):
        json_data = ujson.loads(line)
        if (json_data["type"] == "ForkEvent"):
            fork_event.append(parse_fork_event(json_data))
        elif (json_data["type"] == "WatchEvent"):
            watch_event.append(parse_watch_event(json_data))
        elif (json_data["type"] == "PullRequestEvent"):
            pr_event.append(parse_pull_request_events(json_data))
        elif (json_data["type"] == "PullRequestReviewCommentEvent"):
            pr_reviewcomment_event.append(parse_pull_request_review_comment_events(json_data))
    f.close()

# %%
for hour in range(0, 24):
    with gzip.open('2016-02-07-'+str(hour)+'.json.gz') as f:   
        for i, line in enumerate(f):
            json_data = ujson.loads(line)
            if (json_data["type"] == "ForkEvent"):
                fork_event.append(parse_fork_event(json_data))
            elif (json_data["type"] == "WatchEvent"):
                watch_event.append(parse_watch_event(json_data))
            elif (json_data["type"] == "PullRequestEvent"):
                pr_event.append(parse_pull_request_events(json_data))
            elif (json_data["type"] == "PullRequestReviewCommentEvent"):
                pr_reviewcomment_event.append(parse_pull_request_review_comment_events(json_data))
        f.close()

# %%
watch_df = pandas.DataFrame.from_dict(watch_event, orient='columns', dtype=None)
fork_df = pandas.DataFrame.from_dict(fork_event, orient='columns', dtype=None)
pr_df = pandas.DataFrame.from_dict(pr_event, orient='columns', dtype=None)
pr_rc_df = pandas.DataFrame.from_dict(pr_reviewcomment_event, orient='columns', dtype=None)

# %%
fork_df.head()
# Out:
#    actor_id actor_login            created_at      event language       org  \
# 0    147788       rapzo  2016-02-07T00:00:02Z  ForkEvent     None   3284117
# 1   8035580  jfaquinojr  2016-02-07T00:00:16Z  ForkEvent     None   3195020
# 2  16857734     n1cfury  2016-02-07T00:00:24Z  ForkEvent   Python     False
# 3   2496411   dimitarsp  2016-02-07T00:00:27Z  ForkEvent     None     False
# 4  11396139    migueldf  2016-02-07T00:00:28Z  ForkEvent     None  13573168
#
#      org_id   repo_id                                   repo_name  \
# 0   3284117   8474328                 karma-runner/karma-coverage
# 1   3195020  12004332                      ligershark/side-waffle
# 2       NaN  49541658  theabraxas/IT-Infrastructure-Super-Utility
# 3       NaN  20274542                   pitiwazou/Scripts-Blender
# 4  13573168  40633703   jhu-ep-coursera/fullstack-course1-module3
#
#    stargazers_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
frames = [pr_df, pr_rc_df, fork_df]
combined = pandas.concat(frames)
combined.head()
# Out:
#    actor_id      actor_login            created_at  \
# 0    622699   harshavardhana  2016-02-07T00:00:03Z
# 1   1977052  corey-hammerton  2016-02-07T00:00:04Z
# 2  13547129            Excoh  2016-02-07T00:00:05Z
# 3    622699   harshavardhana  2016-02-07T00:00:07Z
# 4   2207561    samchrisinger  2016-02-07T00:00:08Z
#
#                       description             event    language    org  \
# 0                   Minio Browser  PullRequestEvent  JavaScript   True
# 1       Web frontend for PuppetDB  PullRequestEvent      Python   True
# 2  Test GitHub and its functions.  PullRequestEvent        None  False
# 3                   Minio Browser  PullRequestEvent  JavaScript   True
# 4                                  PullRequestEvent  JavaScript   True
#
#     org_id   repo_id     repo_name  stargazers_count
# 0   695951  45657978  miniobrowser                 6
# 1  8693967  11746441   puppetboard               409
# 2      NaN  51227866   hello-world                 0
# 3   695951  45657978  miniobrowser                 6
# 4  3344584  50667950    exp-addons                 0

# %% [markdown]
# ### Munge and reformat Repo information

# %%
latest_by_repoid = combined.sort('created_at', ascending= False).drop_duplicates(subset="repo_id")
print(len(latest_by_repoid))
latest_by_repoid['description'] = latest_by_repoid['description'].fillna('') # get rid of nans
latest_by_repoid['org_id'] = latest_by_repoid['org_id'].fillna(0) # org_id of 0 means no org associated

repo_info = latest_by_repoid[['repo_id', 'repo_name', 'description', 'language', 'stargazers_count', 'org_id']]
# Out:
# 18316
# /Users/sperrochsy/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
repo_info.tail()
# Out:
#     repo_id                    repo_name  \
# 9  38230607                     lanterna
# 8  23524933                 ansible-ferm
# 7  48774945                        vader
# 2  51227866                  hello-world
# 0   8474328  karma-runner/karma-coverage
#
#                                      description    language  \
# 9      Java library for creating text-based GUIs        Java
# 8            Manage iptables firewall using ferm       Shell
# 7  Codename for new Node.js/Express UPTV website  JavaScript
# 2                 Test GitHub and its functions.        None
# 0                                                       None
#
#    stargazers_count   org_id
# 9               202        0
# 8                14  8523739
# 7                 0        0
# 2                 0        0
# 0                 0  3284117

# %% [markdown]
# ### Insert Rows into DB

# %%
import psycopg2
 
import sys
 
db_con = None

# %%
db_con = psycopg2.connect(database='halcyon', user='postgres', password='hi')
cursor = db_con.cursor()

# %% [markdown]
# #### Upsert Repository information (insert all rows as single transaction)

# %%
for index, row in repo_info.iterrows():
    
    sql_str = """INSERT INTO halcyon."Test_Repos" ( id, name, description, language, num_stars, org) 
                 VALUES (%s, %s, %s, %s, %s, %s)
                 ON CONFLICT (id) DO UPDATE SET 
                 name=excluded.name, description=excluded.description,
                 language=excluded.language, num_stars=excluded.num_stars;"""
        
    cursor.execute(sql_str, (row['repo_id'], row['repo_name'], row['description'], row['language'], row['stargazers_count'], row['org_id']))
db_con.commit()

# %% [markdown]
# #### Clean up Watch Events and put them into DB

# %%
watch_df.head()
# Out:
#     action  actor_id        actor_login            created_at       event  \
# 0  started   2054138           hyrmedia  2016-02-07T00:00:03Z  WatchEvent
# 1  started   2086265             ovgu12  2016-02-07T00:00:05Z  WatchEvent
# 2  started   1407119             ymattw  2016-02-07T00:00:05Z  WatchEvent
# 3  started   1223190  danielvestergaard  2016-02-07T00:00:06Z  WatchEvent
# 4  started    142254        bloudermilk  2016-02-07T00:00:08Z  WatchEvent
#
#      org   org_id   repo_id                        repo_name
# 0  False      NaN  19133534  EvanOxfeld/angular-selectize.js
# 1   True  2185347    519390                    emmetio/emmet
# 2   True   647025   1446474                  pypa/virtualenv
# 3   True    57059   9157414                      scala/async
# 4  False      NaN  25670446      tomchentw/react-google-maps

# %%
watch_df['date'] = watch_df['created_at'].map(lambda date_str: date_str.split('T')[0])
watch_df['hour'] = watch_df['created_at'].map(lambda date_str: date_str.split('T')[1].split(':')[0])
#watch_df['hour'] = watch_df['created_at'].split('T')[1].split(':')[0]

# %%
watch_df.head()
# Out:
#     action  actor_id        actor_login            created_at       event  \
# 0  started   2054138           hyrmedia  2016-02-07T00:00:03Z  WatchEvent
# 1  started   2086265             ovgu12  2016-02-07T00:00:05Z  WatchEvent
# 2  started   1407119             ymattw  2016-02-07T00:00:05Z  WatchEvent
# 3  started   1223190  danielvestergaard  2016-02-07T00:00:06Z  WatchEvent
# 4  started    142254        bloudermilk  2016-02-07T00:00:08Z  WatchEvent
#
#      org   org_id   repo_id                        repo_name        date hour
# 0  False      NaN  19133534  EvanOxfeld/angular-selectize.js  2016-02-07   00
# 1   True  2185347    519390                    emmetio/emmet  2016-02-07   00
# 2   True   647025   1446474                  pypa/virtualenv  2016-02-07   00
# 3   True    57059   9157414                      scala/async  2016-02-07   00
# 4  False      NaN  25670446      tomchentw/react-google-maps  2016-02-07   00

# %% [markdown]
# ### Group Watches and insert into DB

# %%
grouped_watches = pandas.core.frame.DataFrame({'count' : watch_df.groupby(['repo_id', 'repo_name', 'date']).size().order(ascending=False)}).reset_index()
# Out:
# /Users/sperrochsy/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':

# %%
grouped_watches.head(20)
# Out:
#      repo_id                              repo_name        date  count
# 0   50301368                            p-e-w/maybe  2016-02-07   2059
# 1   51184395       jayphelps/git-blame-someone-else  2016-02-07    675
# 2   48855539                   oduslabs/Console-Kit  2016-02-07    602
# 3   28452637                   kennethreitz/records  2016-02-07    558
# 4   41509732                   zymtom/DidIStealThis  2016-02-07    511
# 5   28457823              FreeCodeCamp/FreeCodeCamp  2016-02-07    470
# 6   35699987                      Hotsotse/Hang-man  2016-02-07    419
# 7   50264296                           jgthms/bulma  2016-02-07    310
# 8    9149146                           pudo/dataset  2016-02-07    293
# 9   51025772             AriaFallah/WebpackTutorial  2016-02-07    288
# 10  50146229                          artf/grapesjs  2016-02-07    207
# 11  50586840                            mjmlio/mjml  2016-02-07    206
# 12  51215534             Lloydaaa/Googl-Library-PHP  2016-02-07    193
# 13  48919987                bmkmanoj/js-by-examples  2016-02-07    151
# 14  42766197  y123456yz/reading-code-of-nginx-1.9.2  2016-02-07    151
# 15  37436473                        Hotsotse/cowsay  2016-02-07    148
# 16  50802162                          buckket/twtxt  2016-02-07    135
# 17  51203084        watson/awesome-computer-history  2016-02-07    129
# 18  26898879     caesar0301/awesome-public-datasets  2016-02-07    122
# 19  49692445             tholman/90s-cursor-effects  2016-02-07    112

# %%
for index, row in grouped_watches.iterrows():
    
    sql_str = """INSERT INTO halcyon."Test_Hourly_Watches" ( repo_id, repo_name, star_count, date, hour) 
                 VALUES (%s, %s, %s, %s, %s);"""
        
    cursor.execute(sql_str, (row['repo_id'], row['repo_name'], row['count'], row['date'], row['hour']))
db_con.commit()

# %% [markdown]
# ### Combine Watches with Repo info to get aggregate stats

# %%
watch_lang = pandas.merge(left=watch_df,right=repo_lang, how='left', left_on='repo_id', right_on='repo_id')

# %%
watch_lang['filled_language'] = watch_lang['language'].fillna('No Language')
watch_lang.head()
# Out:
#     action  actor_id        actor_login            created_at       event  \
# 0  started   2054138           hyrmedia  2016-02-07T00:00:03Z  WatchEvent
# 1  started   2086265             ovgu12  2016-02-07T00:00:05Z  WatchEvent
# 2  started   1407119             ymattw  2016-02-07T00:00:05Z  WatchEvent
# 3  started   1223190  danielvestergaard  2016-02-07T00:00:06Z  WatchEvent
# 4  started    142254        bloudermilk  2016-02-07T00:00:08Z  WatchEvent
#
#      org   org_id   repo_id                        repo_name        date hour  \
# 0  False      NaN  19133534  EvanOxfeld/angular-selectize.js  2016-02-07   00
# 1   True  2185347    519390                    emmetio/emmet  2016-02-07   00
# 2   True   647025   1446474                  pypa/virtualenv  2016-02-07   00
# 3   True    57059   9157414                      scala/async  2016-02-07   00
# 4  False      NaN  25670446      tomchentw/react-google-maps  2016-02-07   00
#
#   language filled_language
# 0      NaN     No Language
# 1      NaN     No Language
# 2      NaN     No Language
# 3      NaN     No Language
# 4      NaN     No Language

# %%
watch_lang[(watch_lang['repo_id'] == 50301368)]
# Out:
#         action  actor_id     actor_login            created_at       event  \
# 52     started   5866758     almightyyeh  2016-02-07T00:01:24Z  WatchEvent
# 72     started    292969        kenlimmj  2016-02-07T00:02:12Z  WatchEvent
# 111    started     48586          galvao  2016-02-07T00:03:57Z  WatchEvent
# 141    started     48586          galvao  2016-02-07T00:04:41Z  WatchEvent
# 142    started   4390935        maddouri  2016-02-07T00:04:41Z  WatchEvent
# 177    started   9091144       james9909  2016-02-07T00:06:27Z  WatchEvent
# 179    started    234136         Braynid  2016-02-07T00:06:35Z  WatchEvent
# 259    started   1509413     gokaygurcan  2016-02-07T00:09:38Z  WatchEvent
# 478    started   1523594        jvperrin  2016-02-07T00:14:32Z  WatchEvent
# 507    started   4040623           mseri  2016-02-07T00:15:28Z  WatchEvent
# 646    started   8656859          vu3jej  2016-02-07T00:18:58Z  WatchEvent
# 664    started   2817002     AydinHassan  2016-02-07T00:19:31Z  WatchEvent
# 875    started  14757464          ebazot  2016-02-07T00:26:47Z  WatchEvent
# 880    started    157817       petteraas  2016-02-07T00:26:53Z  WatchEvent
# 1029   started    730620       roomthily  2016-02-07T00:32:53Z  WatchEvent
# 1121   started   6291467    kurisubrooks  2016-02-07T00:36:37Z  WatchEvent
# 1132   started   2405472         robertg  2016-02-07T00:37:07Z  WatchEvent
# 1307   started   1192339          edubxb  2016-02-07T00:43:39Z  WatchEvent
# 1425   started   1050218      boussouira  2016-02-07T00:49:09Z  WatchEvent
# 1444   started   7460917     AlexSwensen  2016-02-07T00:49:48Z  WatchEvent
# 1456   started  16417098     RyanStankye  2016-02-07T00:49:58Z  WatchEvent
# 1476   started   1574446       panpanini  2016-02-07T00:50:48Z  WatchEvent
# 1517   started   2589943       kevholmes  2016-02-07T00:52:35Z  WatchEvent
# 1531   started    337602         posativ  2016-02-07T00:52:55Z  WatchEvent
# 1957   started   4339931    YeisonVargas  2016-02-07T01:08:39Z  WatchEvent
# 1997   started    907873          boralp  2016-02-07T01:10:16Z  WatchEvent
# 2035   started   1071690       crashfrog  2016-02-07T01:11:43Z  WatchEvent
# 2096   started    692443      tuxmachine  2016-02-07T01:13:50Z  WatchEvent
# 2134   started     20190     junkblocker  2016-02-07T01:15:44Z  WatchEvent
# 2146   started    166637          ulgens  2016-02-07T01:16:39Z  WatchEvent
# ...        ...       ...             ...                   ...         ...
# 43657  started   7316652       smeinecke  2016-02-07T23:14:17Z  WatchEvent
# 43665  started    698921          EriCSN  2016-02-07T23:14:45Z  WatchEvent
# 43693  started   4016501         unixfox  2016-02-07T23:15:40Z  WatchEvent
# 43780  started    205317         andreyz  2016-02-07T23:18:24Z  WatchEvent
# 43789  started   1256183          tcnksm  2016-02-07T23:18:51Z  WatchEvent
# 43825  started    129234  collinanderson  2016-02-07T23:19:47Z  WatchEvent
# 43835  started   1542464       mtpereira  2016-02-07T23:19:58Z  WatchEvent
# 43884  started   6609753           Joyez  2016-02-07T23:21:23Z  WatchEvent
# 43918  started   1807142        joshumax  2016-02-07T23:22:42Z  WatchEvent
# 43926  started    221929            jbgi  2016-02-07T23:23:16Z  WatchEvent
# 43984  started   4682986         Jamesso  2016-02-07T23:25:18Z  WatchEvent
# 44009  started  10014147        findkiko  2016-02-07T23:26:17Z  WatchEvent
# 44019  started   1482341           allo-  2016-02-07T23:26:43Z  WatchEvent
# 44030  started    601955          avanov  2016-02-07T23:27:19Z  WatchEvent
# 44052  started    185634         fespino  2016-02-07T23:28:10Z  WatchEvent
# 44064  started    250673            norg  2016-02-07T23:28:27Z  WatchEvent
# 44107  started    195060      killerswan  2016-02-07T23:29:59Z  WatchEvent
# 44142  started   1014398       homelinen  2016-02-07T23:31:09Z  WatchEvent
# 44335  started  10381738          946336  2016-02-07T23:38:29Z  WatchEvent
# 44341  started   1909185        ccramiro  2016-02-07T23:38:37Z  WatchEvent
# 44344  started   4369174          Keyaku  2016-02-07T23:38:44Z  WatchEvent
# 44384  started   1432730          benley  2016-02-07T23:40:06Z  WatchEvent
# 44397  started   4110995   IanBoyanZhang  2016-02-07T23:40:42Z  WatchEvent
# 44561  started   9094330            0x27  2016-02-07T23:46:43Z  WatchEvent
# 44713  started   3646270         spaceoi  2016-02-07T23:52:23Z  WatchEvent
# 44745  started    559321      iamstarkov  2016-02-07T23:53:16Z  WatchEvent
# 44795  started    563778        jprostko  2016-02-07T23:55:31Z  WatchEvent
# 44877  started   2396815        ffunenga  2016-02-07T23:58:30Z  WatchEvent
# 44896  started   6690422       wmeingott  2016-02-07T23:58:58Z  WatchEvent
# 44897  started   4449661     blidarescub  2016-02-07T23:58:59Z  WatchEvent
#
#          org  org_id   repo_id    repo_name        date hour language  \
# 52     False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 72     False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 111    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 141    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 142    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 177    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 179    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 259    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 478    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 507    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 646    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 664    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 875    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 880    False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1029   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1121   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1132   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1307   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1425   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1444   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1456   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1476   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1517   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1531   False     NaN  50301368  p-e-w/maybe  2016-02-07   00      NaN
# 1957   False     NaN  50301368  p-e-w/maybe  2016-02-07   01      NaN
# 1997   False     NaN  50301368  p-e-w/maybe  2016-02-07   01      NaN
# 2035   False     NaN  50301368  p-e-w/maybe  2016-02-07   01      NaN
# 2096   False     NaN  50301368  p-e-w/maybe  2016-02-07   01      NaN
# 2134   False     NaN  50301368  p-e-w/maybe  2016-02-07   01      NaN
# 2146   False     NaN  50301368  p-e-w/maybe  2016-02-07   01      NaN
# ...      ...     ...       ...          ...         ...  ...      ...
# 43657  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43665  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43693  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43780  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43789  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43825  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43835  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43884  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43918  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43926  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 43984  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44009  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44019  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44030  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44052  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44064  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44107  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44142  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44335  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44341  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44344  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44384  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44397  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44561  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44713  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44745  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44795  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44877  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44896  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
# 44897  False     NaN  50301368  p-e-w/maybe  2016-02-07   23      NaN
#
#       filled_language
# 52        No Language
# 72        No Language
# 111       No Language
# 141       No Language
# 142       No Language
# 177       No Language
# 179       No Language
# 259       No Language
# 478       No Language
# 507       No Language
# 646       No Language
# 664       No Language
# 875       No Language
# 880       No Language
# 1029      No Language
# 1121      No Language
# 1132      No Language
# 1307      No Language
# 1425      No Language
# 1444      No Language
# 1456      No Language
# 1476      No Language
# 1517      No Language
# 1531      No Language
# 1957      No Language
# 1997      No Language
# 2035      No Language
# 2096      No Language
# 2134      No Language
# 2146      No Language
# ...               ...
# 43657     No Language
# 43665     No Language
# 43693     No Language
# 43780     No Language
# 43789     No Language
# 43825     No Language
# 43835     No Language
# 43884     No Language
# 43918     No Language
# 43926     No Language
# 43984     No Language
# 44009     No Language
# 44019     No Language
# 44030     No Language
# 44052     No Language
# 44064     No Language
# 44107     No Language
# 44142     No Language
# 44335     No Language
# 44341     No Language
# 44344     No Language
# 44384     No Language
# 44397     No Language
# 44561     No Language
# 44713     No Language
# 44745     No Language
# 44795     No Language
# 44877     No Language
# 44896     No Language
# 44897     No Language
#
# [2059 rows x 13 columns]

# %%
watch_lang.groupby(['repo_id', 'repo_name','filled_language', 'date', 'hour']).size().order(ascending=False).head()
# Out:
# /Users/sperrochsy/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# repo_id   repo_name                   filled_language  date        hour
# 35699987  Hotsotse/Hang-man           No Language      2016-02-07  02      410
# 48855539  oduslabs/Console-Kit        No Language      2016-02-07  18      408
# 41509732  zymtom/DidIStealThis        No Language      2016-02-07  14      354
# 51215534  Lloydaaa/Googl-Library-PHP  No Language      2016-02-07  00      175
# 48855539  oduslabs/Console-Kit        No Language      2016-02-07  19      168
# dtype: int64

# %%
repo_info.groupby
# Out:
#        repo_id                                          repo_name  \
# 1307  48862284  learn-co-students/sinatra-integrating-models-w...
# 1077  26295345                                      dotnet/corefx
# 1306  40944209                           mgwidmann/scrivener_html
# 2960  50800317                           ios-candidate-assignment
# 2961  30210041                                            BotBits
# 1305  48904888                         Twentysix26/Red-DiscordBot
# 2959  50839889                                          WPAppTest
# 1304   6050093                            guybedford/require-less
# 2958  16844474                                             clappr
# 1076  15802645                              withassociates/slices
# 2957  44527927                                         tagmanager
# 1075  46841594                          ryosukemaehira/protospace
# 1303   5918619                             ros-infrastructure/rep
# 1302  20429943  numbbbbb/the-swift-programming-language-in-chi...
# 1301  43337713                              joshuaavalon/CardGame
# 2956  47145318                                          SayKitSDK
# 1300  50691315                           craftedjs/crafted-schema
# 1299  43994050                                     Thinklion/news
# 2954   7407662                                       openxml-docx
# 2955  47214984                                            GOV310L
# 2952   3390243                                              servo
# 1298  23231854                  kottenator/jquery-circle-progress
# 2953  50368226                                 gci15.fossasia.org
# 1297   7817373                                     AlloyTeam/JMUI
# 1073    930571                                    droolsjbpm/jbpm
# 1074  16817497                                          juju/docs
# 1296  49451363                            Agromaan/git-repo-test1
# 2950  49343314                                               fuma
# 1071  45936895                              Automattic/wp-calypso
# 2949  10391073                                       edx-platform
# ...        ...                                                ...
# 31    44007117                                           leafbird
# 29     3452519                                  Custom-Meta-Boxes
# 28    13181035                                          traverson
# 26    19040482                                          concrete5
# 25    17325575                                               GBE2
# 23    24053165                                             clarat
# 9     10410764                        umano/AndroidSlidingUpPanel
# 22    18717762                                       entity_embed
# 21    50831634                                     sepamail-front
# 7     23585945                           Stamplay/stamplay-js-sdk
# 5     12808420                          telefonicaid/fiware-orion
# 18    50685905                          intro-to-looping.js-v-000
# 17    49567567                                          PostBulls
# 15     7262203                                          xo-server
# 12    46802649                                    conda-build-all
# 10     8882852                                       libmaxminddb
# 6     33316888                    MicrosoftLearning/QueryingT-SQL
# 8     23576685                                   debops-playbooks
# 7     30533398                                           eris-cli
# 5     32575162             CumulusNetworks/example-ospfunnum-chef
# 4     50778866                                    pi408637535/jty
# 3     33066290          CumulusNetworks/example-ospfunnum-ansible
# 2      5831189                                        hapijs/hoek
# 4     40319779                                             energy
# 2     49657992                                             trainX
# 1     49424455                rhevm-qe-automation/python-rrmngmnt
# 1     41592744                        AllThingsSmitty/css-protips
# 1      3723999                                       haskell-mode
# 0      1388245                           loopj/android-async-http
# 0     23839256                              edx/edx-documentation
#
#                                             description     language  \
# 1307                                                            None
# 1077                                                              C#
# 1306                                                            None
# 2960                           iOS Candidate Assignment         None
# 2961  An Everybody Edits framework designed for perf...           C#
# 1305                                                            None
# 2959                                                             PHP
# 1304                                                            None
# 2958   :clapper: An extensible media player for the web   JavaScript
# 1076                                                            Ruby
# 2957                                    The tag manager   JavaScript
# 1075                                                      JavaScript
# 1303                                                            None
# 1302                                                            None
# 1301                                                            None
# 2956  Framework for building voice enabled applicati...         HTML
# 1300                                                            None
# 1299                                                            None
# 2954                       Create .docx files with Ruby         Ruby
# 2955                         Intro to American Politics          CSS
# 2952                           The Servo Browser Engine         None
# 1298                                                            None
# 2953                          FOSSASIA GCI Site 2015/16          CSS
# 1297                                                      JavaScript
# 1073                                                            Java
# 1074                                                          Smarty
# 1296                                                            None
# 2950                         Fussball Manager for Slack   JavaScript
# 1071                                                      JavaScript
# 2949  The Open edX platform, the software that power...       Python
# ...                                                 ...          ...
# 31    Leafbird is an UI builder based in templates u...   JavaScript
# 29    Lets you easily create metaboxes with custom f...          PHP
# 28                                                        JavaScript
# 26        Official repository for concrete5 development          PHP
# 25    Total rewrite of GBE original PHP into Python ...       Python
# 23                     An Open Source Charity Directory         Ruby
# 9                                                               None
# 22    Allows any entity to be embedded using a WYSIW...          PHP
# 21                                                        JavaScript
# 7                                                         JavaScript
# 5                                                                C++
# 18                                                        JavaScript
# 17                                                              HTML
# 15                        Server part of Xen Orchestra.   JavaScript
# 12                                                            Python
# 10             C library for the MaxMind DB file format            C
# 6                                                               None
# 8              Ansible playbooks used by DebOps project       Python
# 7     Eris is a platform for building, testing, main...           Go
# 5                                                               None
# 4                                                               None
# 3                                                               None
# 2                                                               None
# 4           Artsy Folio, The Partner iPhone / iPad app.  Objective-C
# 2                              project for train system   JavaScript
# 1                                                             Python
# 1                                                               None
# 1                                Emacs mode for Haskell   Emacs Lisp
# 0                                                               None
# 0                                                           Makefile
#
#       stargazers_count    org_id
# 1307                 0   8825476
# 1077              9054   9141961
# 1306                 0         0
# 2960                 0         0
# 2961                 8         0
# 1305                 0         0
# 2959                 0         0
# 1304                 0         0
# 2958              2674  10685859
# 1076                32     13455
# 2957                 2    164318
# 1075                 0         0
# 1303                 0   2328632
# 1302                 0         0
# 1301                 0         0
# 2956                 5   9219926
# 1300                 0  16955393
# 1299                 0         0
# 2954                 6  14169851
# 2955                 0         0
# 2952              5589   2566135
# 1298                 0         0
# 2953                 0         0
# 1297                 0   1503033
# 1073               433    517980
# 1074                12   4604548
# 1296                 0         0
# 2950                 1         0
# 1071              6715    887802
# 2949              2375   3179841
# ...                ...       ...
# 31                   0         0
# 29                 415    644666
# 28                 155         0
# 26                 247    657929
# 25                   1         0
# 23                   5   8734408
# 9                    0   4552937
# 22                  19   7276699
# 21                   0  15213353
# 7                    0   6942310
# 5                   38    968363
# 18                   0   8825476
# 17                   0         0
# 15                  50   2064170
# 12                  12   1391487
# 10                 117   1181834
# 6                    0  10467123
# 8                  203   8523739
# 7                   43   7984777
# 5                    0   4306877
# 4                    0         0
# 3                    0   4306877
# 2                    0   3774533
# 4                  105    546231
# 2                    0         0
# 1                    0  16609215
# 1                    0         0
# 1                  671    450574
# 0                    0         0
# 0                   31   3179841
#
# [2878 rows x 6 columns]
